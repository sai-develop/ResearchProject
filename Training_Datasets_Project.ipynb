# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-develop/ResearchProject/blob/master/Training_Datasets_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.enable_eager_execution()

# %%
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['mnist_test.csv'].decode('utf-8')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-11fd2c7c1d0c> in <module>()
#       1 import pandas as pd
#       2 import io
# ----> 3 train_data = pd.read_csv(io.StringIO(uploaded['mnist_test.csv'].decode('utf-8')))
#
# NameError: name 'uploaded' is not defined

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b6317744-5404-4bb9-beca-5eebaabf7904" name="files[]" multiple disabled />
#      <output id="result-b6317744-5404-4bb9-beca-5eebaabf7904">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wisdm-dataset.zip to wisdm-dataset.zip

# %%
test_data = pd.read_arff('/content/gdrive/My Drive/ProjectDatasets/wisdm-dataset/data_1600_accel_phone.arff'
# Out:
#   File "<ipython-input-13-4b52ce2d7741>", line 1
#     test_data = pd.read_arff('/content/gdrive/My Drive/ProjectDatasets/wisdm-dataset/data_1600_accel_phone.arff'
#                                                                                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
from google.colab import files
def getCSVFromArff('/content/gdrive/My Drive/ProjectDatasets/wisdm-dataset/data_1600_accel_phone.arff'):
	with open(fileName + '.arff', 'r') as fin:
		data = fin.read().splitlines(True)
	i = 0
	cols = []
	for line in data:
		line = line.lower()
		if ('@data' in line):
			i+= 1
			break
		else:
			#print line
			i+= 1
			if (line.startswith('@attribute')):
				if('{' in line):
					cols.append(line[11:line.index('{')-1])
				else:
					cols.append(line[11:line.index(' ', 11)])
	headers = ",".join(cols)
	with open(fileName + '.csv', 'w') as fout:
		fout.write(headers)
		fout.write('\n')
		fout.writelines(data[i:])

getCSVFromArff("data_1600_accel_phone")				# enter filename here (without extension)
# Out:
#   File "<ipython-input-1-48019a44fe78>", line 2
#     def getCSVFromArff('/content/gdrive/My Drive/ProjectDatasets/wisdm-dataset/data_1600_accel_phone.arff'):
#                                                                                                          ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import io
"""trans multi-label *.arff file to *.csv file."""
import re
def trans_arff2csv(file_in, file_out):
    """trans *.arff file to *.csv file."""
    columns = []
    data = []
    with open(file_in, 'r') as f:
        data_flag = 0
        for line in f:
            if line[:2] == '@a':
                # find indices
                indices = [i for i, x in enumerate(line) if x == ' ']
                columns.append(re.sub(r'^[\'\"]|[\'\"]$|\\+', '', line[indices[0] + 1:indices[-1]]))
            elif line[:2] == '@d':
                data_flag = 1
            elif data_flag == 1:
                data.append(line)

    content = ','.join(columns) + '\n' + ''.join(data)

    # save to file
    with open(file_out, 'w') as f:
        f.write(content)


if __name__ == '__main__':
    from multi_label.arff2csv import trans_arff2csv

    # setting arff file path
    file_attr_in = r'C:\Users\ATUL\Desktop\Arden_Assessment2019\ResearchProject\DataSets\wisdm-dataset\wisdm-dataset\arff_files\phone\data_1600_accel_phone.arff'
    # setting output csv file path
    file_csv_out = r"C:\Users\ATUL\Desktop\Arden_Assessment2019\ResearchProject\DataSets\wisdm-dataset\wisdm-dataset\arff_files\phone\data_1600_accel_phone.csv"
    # trans
    trans_arff2csv(file_attr_in, file_csv_out)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-5ec759c2f0bf> in <module>()
#      28
#      29 if __name__ == '__main__':
# ---> 30     from multi_label.arff2csv import trans_arff2csv
#      31
#      32     # setting arff file path
#
# ModuleNotFoundError: No module named 'multi_label'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # New Section

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fce8597e-5367-4179-9d7d-3aada93cb0a3" name="files[]" multiple disabled />
#      <output id="result-fce8597e-5367-4179-9d7d-3aada93cb0a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1600_accel_phone.csv to csv_result-data_1600_accel_phone.csv

# %%
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1600_accel_phone.csv'].decode('utf-8')))

# %%
train_data.head()
# Out:
#    id ACTIVITY     X0     X1  ...     XZCOR     YZCOR  RESULTANT  class
# 0   1        A  0.235  0.470  ...  0.164468 -0.110722   10.05180   1600
# 1   2        A  0.275  0.440  ...  0.215680 -0.034375   10.11710   1600
# 2   3        A  0.320  0.430  ...  0.272380 -0.077274    9.98384   1600
# 3   4        A  0.315  0.495  ...  0.203131  0.015328   10.10600   1600
# 4   5        A  0.215  0.455  ...  0.238500 -0.009870   10.05210   1600
#
# [5 rows x 94 columns]

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1600_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1601_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1602_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1603_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1604_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1605_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1606_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1607_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1608_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1609_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1610_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1611_accel_phone.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-de6301f1-8543-43c8-adab-c942d2a845f0" name="files[]" multiple disabled />
#      <output id="result-de6301f1-8543-43c8-adab-c942d2a845f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1600_accel_phone.csv to csv_result-data_1600_accel_phone.csv
# Saving csv_result-data_1601_accel_phone.csv to csv_result-data_1601_accel_phone.csv
# Saving csv_result-data_1602_accel_phone.csv to csv_result-data_1602_accel_phone.csv
# Saving csv_result-data_1603_accel_phone.csv to csv_result-data_1603_accel_phone.csv
# Saving csv_result-data_1604_accel_phone.csv to csv_result-data_1604_accel_phone.csv
# Saving csv_result-data_1605_accel_phone.csv to csv_result-data_1605_accel_phone.csv
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1612_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1613_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1615_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1616_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1617_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1618_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1619_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1620_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1621_accel_phone.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-395d5650-7a41-44c3-9c88-5a692234ee95" name="files[]" multiple disabled />
#      <output id="result-395d5650-7a41-44c3-9c88-5a692234ee95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1612_accel_phone.csv to csv_result-data_1612_accel_phone (1).csv
# Saving csv_result-data_1613_accel_phone.csv to csv_result-data_1613_accel_phone (1).csv
# Saving csv_result-data_1615_accel_phone.csv to csv_result-data_1615_accel_phone (1).csv
# Saving csv_result-data_1616_accel_phone.csv to csv_result-data_1616_accel_phone (1).csv
# Saving csv_result-data_1617_accel_phone.csv to csv_result-data_1617_accel_phone (1).csv
# Saving csv_result-data_1618_accel_phone.csv to csv_result-data_1618_accel_phone (1).csv
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1622_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1623_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1624_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1625_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1626_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1627_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1628_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1629_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1630_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1631_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1632_accel_phone.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-827512e5-1684-4b26-b55f-aea841f087af" name="files[]" multiple disabled />
#      <output id="result-827512e5-1684-4b26-b55f-aea841f087af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1622_accel_phone.csv to csv_result-data_1622_accel_phone.csv
# Saving csv_result-data_1623_accel_phone.csv to csv_result-data_1623_accel_phone.csv
# Saving csv_result-data_1624_accel_phone.csv to csv_result-data_1624_accel_phone.csv
# Saving csv_result-data_1625_accel_phone.csv to csv_result-data_1625_accel_phone.csv
# Saving csv_result-data_1626_accel_phone.csv to csv_result-data_1626_accel_phone.csv
# Saving csv_result-data_1627_accel_phone.csv to csv_result-data_1627_accel_phone.csv
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1633_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1634_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1635_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1636_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1637_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1638_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1639_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1640_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1641_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1642_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1643_accel_phone.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-86091473-9365-4809-b540-0c866726ee8f" name="files[]" multiple disabled />
#      <output id="result-86091473-9365-4809-b540-0c866726ee8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1633_accel_phone.csv to csv_result-data_1633_accel_phone.csv
# Saving csv_result-data_1634_accel_phone.csv to csv_result-data_1634_accel_phone.csv
# Saving csv_result-data_1635_accel_phone.csv to csv_result-data_1635_accel_phone.csv
# Saving csv_result-data_1636_accel_phone.csv to csv_result-data_1636_accel_phone.csv
# Saving csv_result-data_1637_accel_phone.csv to csv_result-data_1637_accel_phone.csv
# Saving csv_result-data_1638_accel_phone.csv to csv_result-data_1638_accel_phone.csv
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1644_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1645_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1646_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1647_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1648_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1649_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1650_accel_phone.csv'].decode('utf-8')))
train_data.head()
# Out:
#      <input type="file" id="files-bf8b57c9-0d98-4b50-815e-121810220858" name="files[]" multiple disabled />
#      <output id="result-bf8b57c9-0d98-4b50-815e-121810220858">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1644_accel_phone.csv to csv_result-data_1644_accel_phone.csv
# Saving csv_result-data_1645_accel_phone.csv to csv_result-data_1645_accel_phone.csv
# Saving csv_result-data_1646_accel_phone.csv to csv_result-data_1646_accel_phone.csv
# Saving csv_result-data_1647_accel_phone.csv to csv_result-data_1647_accel_phone.csv
# Saving csv_result-data_1648_accel_phone.csv to csv_result-data_1648_accel_phone.csv
# Saving csv_result-data_1649_accel_phone.csv to csv_result-data_1649_accel_phone.csv
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
import io
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1600_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1601_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1602_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1603_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1604_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1605_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1606_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1607_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1608_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1609_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1610_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1611_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1612_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1613_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1615_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1616_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1617_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1618_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1619_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1620_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1621_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1622_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1623_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1624_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1625_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1626_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1627_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1628_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1629_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1630_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1631_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1632_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1633_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1634_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1635_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1636_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1637_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1638_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1639_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1640_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1641_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1642_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1643_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1644_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1645_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1646_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1647_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1648_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1649_accel_phone.csv'].decode('utf-8')))
train_data = pd.read_csv(io.StringIO(uploaded['csv_result-data_1650_accel_phone.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-75df53b7-1fb9-4e58-bb7d-75185d646fbc" name="files[]" multiple disabled />
#      <output id="result-75df53b7-1fb9-4e58-bb7d-75185d646fbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csv_result-data_1600_accel_phone.csv to csv_result-data_1600_accel_phone.csv
# Saving csv_result-data_1601_accel_phone.csv to csv_result-data_1601_accel_phone.csv
# Saving csv_result-data_1602_accel_phone.csv to csv_result-data_1602_accel_phone.csv
# Saving csv_result-data_1603_accel_phone.csv to csv_result-data_1603_accel_phone.csv
# Saving csv_result-data_1604_accel_phone.csv to csv_result-data_1604_accel_phone.csv
# Saving csv_result-data_1605_accel_phone.csv to csv_result-data_1605_accel_phone.csv
# ...

# %%
train_data.head(5)
# Out:
#    id ACTIVITY     X0     X1  ...     XZCOR     YZCOR  RESULTANT  class
# 0   1        A  0.230  0.235  ... -0.073767  0.223811   11.51220   1650
# 1   2        A  0.975  0.020  ...  0.026102 -0.366805   10.66480   1650
# 2   3        A  1.000  0.000  ... -0.049683 -0.101471   10.11240   1650
# 3   4        A  0.995  0.005  ...  0.281892 -0.232531   10.19920   1650
# 4   5        A  0.990  0.010  ...  0.112605 -0.458078    9.78553   1650
#
# [5 rows x 94 columns]

# %%
import tensorflow as tf
tf.enable_eager_execution()
print(tf.__version__)
#defaults=[tf.int32]*94
dataset=tf.contrib.data.CsvDataset(['csv_result-data_1615_accel_phone.csv'],defaults)
print(list(dataset.take(1)))
col_names=['elevation','aspect','slope']
def_parse_csv_row(*vals);
soil_type_t=tf.convert_to_tensor(vals[1:94])
feat_vals=vals[:1]+(soil_type_t,vals[94])
features= dict(zip(col_names, feat_vals))
class_label=tf.argmax(row_vals[1:94], axis=0)
dataset= dataset.map(_parse_csv_row).batch(94)
# Out:
# 1.15.0
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-13-de9f9c13f275> in <module>()
#       4 #defaults=[tf.int32]*94
#       5 dataset=tf.contrib.data.CsvDataset(['csv_result-data_1615_accel_phone.csv'],defaults)
# ----> 6 print(list(dataset.take(1)))
#       7 col_names=['elevation','aspect','slope']
#       8 def_parse_csv_row(*vals);
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py in __next__(self)
#     620
#     621   def __next__(self):  # For Python 3 compatibility
# --> 622     return self.next()
#     623
#     624   def _next_internal(self):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py in next(self)
#     664     """Returns a nested structure of `Tensor`s containing the next element."""
#     665     try:
# --> 666       return self._next_internal()
# ...
